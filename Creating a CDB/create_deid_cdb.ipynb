# %% [markdown]
# # Create a MedCAT CDB

# %%
from medcat.cdb import CDB
from medcat.cat import CAT
from medcat.utils.vocab import Vocab
from medcat.cdb_maker import CDBMaker
from medcat.config import Config
import os
import pandas as pd

import spacy
import en_core_sci_md

# %%
csv_path = 'cui_05082021.csv'  # deid terminology path
output_cdb = '05082021_basic_deid_cdb_wtout_names.dat'  # Name of CDB output

# %% [markdown]
# ## Load /inspect data

# %%
csv = pd.read_csv(csv_path)
csv
# Out:
#                                str    cui      onto tty  tui  sty  \
# 0   de-identification_root_concept  R0000  cat_anon  PN  NaN  NaN
# 1                             name  N1000  cat_anon  PN  NaN  NaN
# 2                  contact_details  C2000  cat_anon  PN  NaN  NaN
# 3            healthcare_identifier  H3000  cat_anon  PN  NaN  NaN
# 4                             date  D4000  cat_anon  PN  NaN  NaN
# 5                        fore_name  N1100  cat_anon  PN  NaN  NaN
# 6                          surname  N1200  cat_anon  PN  NaN  NaN
# 7                         initials  N1300  cat_anon  PN  NaN  NaN
# 8                          address  C2100  cat_anon  PN  NaN  NaN
# 9                     address_line  C2110  cat_anon  PN  NaN  NaN
# 10                        postcode  C2120  cat_anon  PN  NaN  NaN
# 11                telephone_number  C2200  cat_anon  PN  NaN  NaN
# 12                           email  C2300  cat_anon  PN  NaN  NaN
# 13                  identification  C2400  cat_anon  PN  NaN  NaN
# 14                 passport_number  C2410  cat_anon  PN  NaN  NaN
# 15          driving_licence_number  C2420  cat_anon  PN  NaN  NaN
# 16              national_insurance  C2430  cat_anon  PN  NaN  NaN
# 17                      nhs_number  H3100  cat_anon  PN  NaN  NaN
# 18                 hospital_number  H3200  cat_anon  PN  NaN  NaN
# 19     emergency_department_number  H3300  cat_anon  PN  NaN  NaN
# 20                      lab_number  H3400  cat_anon  PN  NaN  NaN
# 21                      gmc_number  H3500  cat_anon  PN  NaN  NaN
# 22                   date_of_birth  H4100  cat_anon  PN  NaN  NaN
# 23                             url  C2500  cat_anon  PN  NaN  NaN
#
#                                                  desc
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   all initials (initials that aren't seperated b...
# 8   address and postcode (including a comma or ful...
# 9   all address line items including city and country
# 10                                      all postcodes
# 11         telephone numbers both mobile and landline
# 12                                    email addresses
# 13                        non hospital identification
# 14                                    passport number
# 15                                    driving licence
# 16                     all national insurance numbers
# 17                                        nhs numbers
# 18  hospital number from kings college hospital an...
# 19  number given by kings college hospital emergen...
# 20               all lab ids used to identify samples
# 21               General Medical Council (GMC) number
# 22                                      date of birth
# 23         all websites associated with an individual

# %%
csv
# Out:
#                                str    cui      onto tty  tui  sty  \
# 0   de-identification_root_concept  R0000  cat_anon  PN  NaN  NaN
# 1                             name  N1000  cat_anon  PN  NaN  NaN
# 2                  contact_details  C2000  cat_anon  PN  NaN  NaN
# 3            healthcare_identifier  H3000  cat_anon  PN  NaN  NaN
# 4                             date  D4000  cat_anon  PN  NaN  NaN
# 5                        fore_name  N1100  cat_anon  PN  NaN  NaN
# 6                          surname  N1200  cat_anon  PN  NaN  NaN
# 7                         initials  N1300  cat_anon  PN  NaN  NaN
# 8                          address  C2100  cat_anon  PN  NaN  NaN
# 9                     address_line  C2110  cat_anon  PN  NaN  NaN
# 10                        postcode  C2120  cat_anon  PN  NaN  NaN
# 11                telephone_number  C2200  cat_anon  PN  NaN  NaN
# 12                           email  C2300  cat_anon  PN  NaN  NaN
# 13                  identification  C2400  cat_anon  PN  NaN  NaN
# 14                 passport_number  C2410  cat_anon  PN  NaN  NaN
# 15          driving_licence_number  C2420  cat_anon  PN  NaN  NaN
# 16              national_insurance  C2430  cat_anon  PN  NaN  NaN
# 17                      nhs_number  H3100  cat_anon  PN  NaN  NaN
# 18                 hospital_number  H3200  cat_anon  PN  NaN  NaN
# 19     emergency_department_number  H3300  cat_anon  PN  NaN  NaN
# 20                      lab_number  H3400  cat_anon  PN  NaN  NaN
# 21                      gmc_number  H3500  cat_anon  PN  NaN  NaN
# 22                   date_of_birth  H4100  cat_anon  PN  NaN  NaN
# 23                             url  C2500  cat_anon  PN  NaN  NaN
#
#                                                  desc
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   all initials (initials that aren't seperated b...
# 8   address and postcode (including a comma or ful...
# 9   all address line items including city and country
# 10                                      all postcodes
# 11         telephone numbers both mobile and landline
# 12                                    email addresses
# 13                        non hospital identification
# 14                                    passport number
# 15                                    driving licence
# 16                     all national insurance numbers
# 17                                        nhs numbers
# 18  hospital number from kings college hospital an...
# 19  number given by kings college hospital emergen...
# 20               all lab ids used to identify samples
# 21               General Medical Council (GMC) number
# 22                                      date of birth
# 23         all websites associated with an individual

# %%
csv.drop(['sty'], axis=1, inplace=True)

# %%
csv.rename(columns={"str": "name",
                     "cui": "cui",
                     "onto": "ontologies",
                     "tty": "name_status",
                     "tui": "type_ids",
                     "desc": "description"}, inplace=True)

# %%
csv['name_status'] = csv['name_status'].replace("PN", "P")

# %%
csv
# Out:
#                               name    cui ontologies name_status  type_ids  \
# 0   de-identification_root_concept  R0000   cat_anon           P       NaN
# 1                             name  N1000   cat_anon           P       NaN
# 2                  contact_details  C2000   cat_anon           P       NaN
# 3            healthcare_identifier  H3000   cat_anon           P       NaN
# 4                             date  D4000   cat_anon           P       NaN
# 5                        fore_name  N1100   cat_anon           P       NaN
# 6                          surname  N1200   cat_anon           P       NaN
# 7                         initials  N1300   cat_anon           P       NaN
# 8                          address  C2100   cat_anon           P       NaN
# 9                     address_line  C2110   cat_anon           P       NaN
# 10                        postcode  C2120   cat_anon           P       NaN
# 11                telephone_number  C2200   cat_anon           P       NaN
# 12                           email  C2300   cat_anon           P       NaN
# 13                  identification  C2400   cat_anon           P       NaN
# 14                 passport_number  C2410   cat_anon           P       NaN
# 15          driving_licence_number  C2420   cat_anon           P       NaN
# 16              national_insurance  C2430   cat_anon           P       NaN
# 17                      nhs_number  H3100   cat_anon           P       NaN
# 18                 hospital_number  H3200   cat_anon           P       NaN
# 19     emergency_department_number  H3300   cat_anon           P       NaN
# 20                      lab_number  H3400   cat_anon           P       NaN
# 21                      gmc_number  H3500   cat_anon           P       NaN
# 22                   date_of_birth  H4100   cat_anon           P       NaN
# 23                             url  C2500   cat_anon           P       NaN
#
#                                           description
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   all initials (initials that aren't seperated b...
# 8   address and postcode (including a comma or ful...
# 9   all address line items including city and country
# 10                                      all postcodes
# 11         telephone numbers both mobile and landline
# 12                                    email addresses
# 13                        non hospital identification
# 14                                    passport number
# 15                                    driving licence
# 16                     all national insurance numbers
# 17                                        nhs numbers
# 18  hospital number from kings college hospital an...
# 19  number given by kings college hospital emergen...
# 20               all lab ids used to identify samples
# 21               General Medical Council (GMC) number
# 22                                      date of birth
# 23         all websites associated with an individual

# %%
csv.to_csv("./cui_05082021.csv", index=False)

# %%
csv.dropna(axis=0,subset=['name'], inplace=True)

# %%
csv[csv.name.isnull()]
# Out:
# Empty DataFrame
# Columns: [name, cui, ontologies, name_status, type_ids, description]
# Index: []

# %%
csv.to_csv("/Users/shek/Downloads/full_cui_medcat040221.csv", index=False)

# %% [markdown]
# ## Create cdb

# %%
config = Config()

# %%
maker = CDBMaker(config)

# %%
cdb = maker.prepare_csvs([csv_path], full_build=True)
# Out:
# Started importing concepts from: cui_05082021.csv
# Current progress: 0% at 0.000s per 0 rows
# Current progress: 4% at 0.277s per 0 rows
# Current progress: 8% at 0.006s per 0 rows
# Current progress: 12% at 0.010s per 0 rows
# Current progress: 17% at 0.009s per 0 rows
# Current progress: 21% at 0.007s per 0 rows
# Current progress: 25% at 0.013s per 0 rows
# Current progress: 29% at 0.011s per 0 rows
# Current progress: 33% at 0.013s per 0 rows
# Current progress: 38% at 0.008s per 0 rows
# Current progress: 42% at 0.011s per 0 rows
# Current progress: 46% at 0.010s per 0 rows
# Current progress: 50% at 0.010s per 0 rows
# Current progress: 54% at 0.011s per 0 rows
# Current progress: 58% at 0.010s per 0 rows
# Current progress: 62% at 0.010s per 0 rows
# Current progress: 67% at 0.010s per 0 rows
# Current progress: 71% at 0.014s per 0 rows
# Current progress: 75% at 0.011s per 0 rows
# Current progress: 79% at 0.009s per 0 rows
# Current progress: 83% at 0.013s per 0 rows
# Current progress: 88% at 0.009s per 0 rows
# Current progress: 92% at 0.008s per 0 rows
# Current progress: 96% at 0.010s per 0 rows

# %%
# Remove all synoymns of concepts (only in rare usecases)
# cdb.addl_info['cui2original_names'] = {}

# %%
cdb.name2cuis
# Out:
# {'de~identification~root~concept': ['R0000'],
#  'name': ['N1000'],
#  'contact~details': ['C2000'],
#  'contact~detail': ['C2000'],
#  'healthcare~identifier': ['H3000'],
#  'date': ['D4000'],
#  'fore~name': ['N1100'],
#  'surname': ['N1200'],
#  'initials': ['N1300'],
#  'initial': ['N1300'],
#  'address': ['C2100'],
#  'address~line': ['C2110'],
#  'postcode': ['C2120'],
#  'telephone~number': ['C2200'],
#  'email': ['C2300'],
#  'identification': ['C2400'],
#  'passport~number': ['C2410'],
#  'driving~licence~number': ['C2420'],
#  'national~insurance': ['C2430'],
#  'nhs~number': ['H3100'],
#  'hospital~number': ['H3200'],
#  'emergency~department~number': ['H3300'],
#  'lab~number': ['H3400'],
#  'gmc~number': ['H3500'],
#  'date~of~birth': ['H4100'],
#  'url': ['C2500']}

# %%
csv
# Out:
#                               name    cui ontologies name_status  type_ids  \
# 0   de-identification_root_concept  R0000   cat_anon           P       NaN
# 1                             name  N1000   cat_anon           P       NaN
# 2                  contact_details  C2000   cat_anon           P       NaN
# 3            healthcare_identifier  H3000   cat_anon           P       NaN
# 4                             date  D4000   cat_anon           P       NaN
# 5                        fore_name  N1100   cat_anon           P       NaN
# 6                          surname  N1200   cat_anon           P       NaN
# 7                         initials  N1300   cat_anon           P       NaN
# 8                          address  C2100   cat_anon           P       NaN
# 9                     address_line  C2110   cat_anon           P       NaN
# 10                        postcode  C2120   cat_anon           P       NaN
# 11                telephone_number  C2200   cat_anon           P       NaN
# 12                           email  C2300   cat_anon           P       NaN
# 13                  identification  C2400   cat_anon           P       NaN
# 14                 passport_number  C2410   cat_anon           P       NaN
# 15          driving_licence_number  C2420   cat_anon           P       NaN
# 16              national_insurance  C2430   cat_anon           P       NaN
# 17                      nhs_number  H3100   cat_anon           P       NaN
# 18                 hospital_number  H3200   cat_anon           P       NaN
# 19     emergency_department_number  H3300   cat_anon           P       NaN
# 20                      lab_number  H3400   cat_anon           P       NaN
# 21                      gmc_number  H3500   cat_anon           P       NaN
# 22                   date_of_birth  H4100   cat_anon           P       NaN
# 23                             url  C2500   cat_anon           P       NaN
#
#                                           description
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   all initials (initials that aren't seperated b...
# 8   address and postcode (including a comma or ful...
# 9   all address line items including city and country
# 10                                      all postcodes
# 11         telephone numbers both mobile and landline
# 12                                    email addresses
# 13                        non hospital identification
# 14                                    passport number
# 15                                    driving licence
# 16                     all national insurance numbers
# 17                                        nhs numbers
# 18  hospital number from kings college hospital an...
# 19  number given by kings college hospital emergen...
# 20               all lab ids used to identify samples
# 21               General Medical Council (GMC) number
# 22                                      date of birth
# 23         all websites associated with an individual

# %%
cdb.save(output_cdb)

# %% [markdown]
# ## Load CDB and inspect

# %%
# load cdb
cdb2 = CDB.load(output_cdb)

# %%
cdb2
