# %% [markdown]
# # Create a MedCAT CDB

# %%
from medcat.cdb import CDB
from medcat.cat import CAT
from medcat.utils.vocab import Vocab
from medcat.cdb_maker import CDBMaker
from medcat.config import Config
import os
import pandas as pd

# %%
csv_path = './cui_040320201.csv'  # deid terminology path
output_cdb = '20210304_basic_deid_cdb_wtout_names.dat'  # Name of CDB output

# %% [markdown]
# ## Load /inspect data

# %%
csv = pd.read_csv(csv_path)

# %%
csv['name_status'] = csv['name_status'].replace("PN", "P")

# %%
csv
# Out:
#                               name    cui ontologies name_status  type_ids  \
# 0   de-identification_root_concept  R0000   cat_anon           P       NaN
# 1                             name  N1000   cat_anon           P       NaN
# 2                  contact_details  C2000   cat_anon           P       NaN
# 3            healthcare_identifier  H3000   cat_anon           P       NaN
# 4                             date  D4000   cat_anon           P       NaN
# 5                        fore_name  N1100   cat_anon           P       NaN
# 6                          surname  N1200   cat_anon           P       NaN
# 7                          address  C2100   cat_anon           P       NaN
# 8                     address_line  C2110   cat_anon           P       NaN
# 9                         postcode  C2120   cat_anon           P       NaN
# 10                telephone_number  C2200   cat_anon           P       NaN
# 11                           email  C2300   cat_anon           P       NaN
# 12                  identification  C2400   cat_anon           P       NaN
# 13                 passport_number  C2410   cat_anon           P       NaN
# 14          driving_licence_number  C2420   cat_anon           P       NaN
# 15              national_insurance  C2430   cat_anon           P       NaN
# 16                      nhs_number  H3100   cat_anon           P       NaN
# 17                 hospital_number  H3200   cat_anon           P       NaN
# 18     emergency_department_number  H3300   cat_anon           P       NaN
# 19                      lab_number  H3400   cat_anon           P       NaN
# 20                   date_of_birth  H4100   cat_anon           P       NaN
# 21                             url  C2500   cat_anon           P       NaN
#
#                                           description
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   address and postcode (including a comma or ful...
# 8   all address line items including city and country
# 9                                       all postcodes
# 10         telephone numbers both mobile and landline
# 11                                    email addresses
# 12                        non hospital identification
# 13                                    passport number
# 14                                    driving licence
# 15                     all national insurance numbers
# 16                                        nhs numbers
# 17  hospital number from kings college hospital an...
# 18  number given by kings college hospital emergen...
# 19               all lab ids used to identify samples
# 20                                      date of birth
# 21         all websites associated with an individual

# %%
csv.rename(columns={"str": "name",
                     "cui": "cui",
                     "onto": "ontologies",
                     "tty": "name_status",
                     "tui": "type_ids",
                     "desc": "description"}, inplace=True)

# %%
csv.drop(['sty'], axis=1, inplace=True)

# %%
csv.to_csv("./cui_040320201.csv", index=False)

# %%
csv.dropna(axis=0,subset=['name'], inplace=True)

# %%
csv[csv.name.isnull()]

# %%
csv.to_csv("/Users/shek/Downloads/full_cui_medcat040221.csv", index=False)

# %% [markdown]
# ## Create cdb

# %%
config = Config()

# %%
maker = CDBMaker(config)

# %%
cdb = maker.prepare_csvs([csv_path], full_build=True)
# Out:
# Started importing concepts from: ./cui_040320201.csv
# Current progress: 0% at 0.000s per 0 rows
# Current progress: 5% at 0.003s per 0 rows
# Current progress: 9% at 0.017s per 0 rows
# Current progress: 14% at 0.016s per 0 rows
# Current progress: 18% at 0.010s per 0 rows
# Current progress: 23% at 0.021s per 0 rows
# Current progress: 27% at 0.036s per 0 rows
# Current progress: 32% at 0.026s per 0 rows
# Current progress: 36% at 0.009s per 0 rows
# Current progress: 41% at 0.005s per 0 rows
# Current progress: 45% at 0.005s per 0 rows
# Current progress: 50% at 0.014s per 0 rows
# Current progress: 55% at 0.003s per 0 rows
# Current progress: 59% at 0.004s per 0 rows
# Current progress: 64% at 0.025s per 0 rows
# Current progress: 68% at 0.005s per 0 rows
# Current progress: 73% at 0.005s per 0 rows
# Current progress: 77% at 0.005s per 0 rows
# Current progress: 82% at 0.005s per 0 rows
# Current progress: 86% at 0.006s per 0 rows
# Current progress: 91% at 0.005s per 0 rows
# Current progress: 95% at 0.004s per 0 rows

# %%
# Remove all synoymns of concepts (only in rare usecases)
cdb.addl_info['cui2original_names'] = {}

# %%
cdb.name2cuis
# Out:
# {'de~identification~root~concept': ['R0000'],
#  'name': ['N1000'],
#  'contact~detail': ['C2000'],
#  'contact~details': ['C2000'],
#  'healthcare~identifier': ['H3000'],
#  'date': ['D4000'],
#  'fore~name': ['N1100'],
#  'surname': ['N1200'],
#  'address': ['C2100'],
#  'address~line': ['C2110'],
#  'postcode': ['C2120'],
#  'telephone~numb': ['C2200'],
#  'telephone~number': ['C2200'],
#  'email': ['C2300'],
#  'identification': ['C2400'],
#  'passport~numb': ['C2410'],
#  'passport~number': ['C2410'],
#  'drive~licence~numb': ['C2420'],
#  'driving~licence~number': ['C2420'],
#  'national~insurance': ['C2430'],
#  'nhs~numb': ['H3100'],
#  'nhs~number': ['H3100'],
#  'hospital~numb': ['H3200'],
#  'hospital~number': ['H3200'],
#  'emergency~department~numb': ['H3300'],
#  'emergency~department~number': ['H3300'],
#  'lab~numb': ['H3400'],
#  'lab~number': ['H3400'],
#  'date~of~birth': ['H4100'],
#  'url': ['C2500']}

# %%
csv
# Out:
#                               name    cui ontologies name_status  type_ids  \
# 0   de-identification_root_concept  R0000   cat_anon           P       NaN
# 1                             name  N1000   cat_anon           P       NaN
# 2                  contact_details  C2000   cat_anon           P       NaN
# 3            healthcare_identifier  H3000   cat_anon           P       NaN
# 4                             date  D4000   cat_anon           P       NaN
# 5                        fore_name  N1100   cat_anon           P       NaN
# 6                          surname  N1200   cat_anon           P       NaN
# 7                          address  C2100   cat_anon           P       NaN
# 8                     address_line  C2110   cat_anon           P       NaN
# 9                         postcode  C2120   cat_anon           P       NaN
# 10                telephone_number  C2200   cat_anon           P       NaN
# 11                           email  C2300   cat_anon           P       NaN
# 12                  identification  C2400   cat_anon           P       NaN
# 13                 passport_number  C2410   cat_anon           P       NaN
# 14          driving_licence_number  C2420   cat_anon           P       NaN
# 15              national_insurance  C2430   cat_anon           P       NaN
# 16                      nhs_number  H3100   cat_anon           P       NaN
# 17                 hospital_number  H3200   cat_anon           P       NaN
# 18     emergency_department_number  H3300   cat_anon           P       NaN
# 19                      lab_number  H3400   cat_anon           P       NaN
# 20                   date_of_birth  H4100   cat_anon           P       NaN
# 21                             url  C2500   cat_anon           P       NaN
#
#                                           description
# 0                   root concept of de-identification
# 1                                surname and forename
# 2     non hospital identification and contact details
# 3                                 hospital derived ID
# 4                                      personal dates
# 5   given name including middle names (each name, ...
# 6                                        all surnames
# 7   address and postcode (including a comma or ful...
# 8   all address line items including city and country
# 9                                       all postcodes
# 10         telephone numbers both mobile and landline
# 11                                    email addresses
# 12                        non hospital identification
# 13                                    passport number
# 14                                    driving licence
# 15                     all national insurance numbers
# 16                                        nhs numbers
# 17  hospital number from kings college hospital an...
# 18  number given by kings college hospital emergen...
# 19               all lab ids used to identify samples
# 20                                      date of birth
# 21         all websites associated with an individual

# %%
cdb.save(output_cdb)

# %% [markdown]
# ## Load CDB and inspect

# %%
# load cdb
cdb2 = CDB.load(output_cdb)

# %%
cdb2
